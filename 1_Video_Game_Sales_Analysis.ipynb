# %% [markdown]
# # Video Game Sales Analysis

# %%
# Import Libreries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#import empiricaldist

# %%
# Read files
# vgs -> Video Game Sales
vgs = pd.read_csv("vgsales.csv")
vgs.info()
vgs.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# ...

# %%
# Handle missing data
vgs["Year"] = vgs["Year"].replace(np.nan, 1900)
display(vgs["Year"].unique())
vgs["Publisher"] = vgs["Publisher"].replace(np.nan, "Unknown")
# Out:
# array([2006., 1985., 2008., 2009., 1996., 1989., 1984., 2005., 1999.,
#        2007., 2010., 2013., 2004., 1990., 1988., 2002., 2001., 2011.,
#        1998., 2015., 2012., 2014., 1992., 1997., 1993., 1994., 1982.,
#        2003., 1986., 2000., 1900., 1995., 2016., 1991., 1981., 1987.,
#        1980., 1983., 2020., 2017.])

# %%
# Change datatypes
# Integers
vgs["Rank"] = vgs["Rank"].astype("int32")
vgs["Year"] = vgs["Year"].astype(str).str.split(".").str[0]
vgs["Year"] = vgs["Year"].astype("int32")
# Change the Genre dtype to categorical
vgs["Genre"] = vgs["Genre"].astype("category")
vgs["Platform"] = vgs["Platform"].astype("category")

# %%
vgs.info()
vgs.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int32
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  category
#  3   Year          16598 non-null  int32
#  4   Genre         16598 non-null  category
#  5   Publisher     16598 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: category(2), float64(5), int32(2), object(2)
# memory usage: 1.0+ MB
#    Rank                      Name Platform  Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# ...

# %%
vgs.describe(include="all")
# Out:
#                 Rank                         Name Platform          Year  \
# count   16598.000000                        16598    16598  16598.000000
# unique           NaN                        11493       31           NaN
# top              NaN  Need for Speed: Most Wanted       DS           NaN
# freq             NaN                           12     2163           NaN
# mean     8300.605254                          NaN      NaN   2004.669117
# std      4791.853933                          NaN      NaN     14.672342
# min         1.000000                          NaN      NaN   1900.000000
# 25%      4151.250000                          NaN      NaN   2003.000000
# 50%      8300.500000                          NaN      NaN   2007.000000
# 75%     12449.750000                          NaN      NaN   2010.000000
# max     16600.000000                          NaN      NaN   2020.000000
#
#          Genre        Publisher      NA_Sales      EU_Sales      JP_Sales  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Visualize the "Unknown" values in the Publisher column
# vgs[vgs["Publisher"] == "Unknown"]

# %%
# Strip the 0 in the column year
# Code to convert the column year into data type
#vgs["Year"] = pd.to_datetime(vgs.Year, format = "%Y")
#Indexator od the year
# vgs['Year'] = pd.DatetimeIndex(vgs['Year']).year

# %%
# display(vgs[vgs["Platform"]=="WS"])
# display(vgs[vgs["Platform"]=="NG"])
# display(vgs[vgs["Platform"]=="DC"])
# display(vgs[vgs["Platform"]=="SCD"])
# display(vgs[vgs["Platform"]=="PC"])

# %%
# Map companies by platform
print("This are the unique platforms in the column platform: ")
for platform in vgs.Platform.unique():
    print(platform, end=" ")
print("______")
company = {
    "Wii" : "Nintendo",
    "NES": "Nintendo",
    "GB" : "Nintendo",
    "DS" : "Nintendo",
    "X360" : "Microsoft",
    "PS3" : "Sony",
    "PS2" : "Sony",
    "SNES" : "Nintendo",
    "GBA" : "Nintendo",
    "3DS" : "Nintendo", 
    "PS4" : "Sony",
    "N64": "Nintendo",
    "PS" : "Sony",
    "XB" : "Microsoft",
    "PC" : "PC",
    "2600" : "Atari",
    "PSP" : "Sony",
    "XOne" : "Microsoft",
    "GC" : "Nintendo",
    "WiiU" : "Nintendo",
    "GEN" : "Sega",
    "DC" : "Sega",
    "PSV" : "Sony",
    "SAT" : "Sega",
    "SCD" : "Sega",
    "WS" : "Bandai",
    "NG" : "SNK Corporation",
    "TG16" : "NEC Corporation",
    "3DO" : "LG Electronics",
    "GG" : "Sega",
    "PCFX" : "NEC Corporation"
}
vgs["Company"] = vgs["Platform"].map(company)
vgs["Company"] = vgs["Company"].astype("category")
vgs.head()
# Out:
# This are the unique platforms in the column platform:
# Wii NES GB DS X360 PS3 PS2 SNES GBA 3DS PS4 N64 PS XB PC 2600 PSP XOne GC WiiU GEN DC PSV SAT SCD WS NG TG16 3DO GG PCFX ______
#    Rank                      Name Platform  Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales   Company
# 0     41.49     29.02      3.77         8.46         82.74  Nintendo
# 1     29.08      3.58      6.81         0.77         40.24  Nintendo
# 2     15.85     12.88      3.79         3.31         35.82  Nintendo
# 3     15.75     11.01      3.28         2.96         33.00  Nintendo
# ...

# %%
vgs.Company.dtype
# Out:
# CategoricalDtype(categories=['Atari', 'Bandai', 'LG Electronics', 'Microsoft',
#                   'NEC Corporation', 'Nintendo', 'PC', 'SNK Corporation',
#                   'Sega', 'Sony'],
# , ordered=False)

# %%
sony = vgs[vgs["Company"]== "Sony"].Global_Sales.sum()
sony
# Out:
# 3580.4500000000003

# %%
total_sales = vgs.pivot_table(index="Genre", columns="Company", values="Global_Sales", aggfunc="sum").sum().sort_values(ascending=False)
total_sales = total_sales.reset_index()
total_sales.columns = ["Company", "Total_Sales"]
total_sales
# Out:
#            Company  Total_Sales
# 0             Sony      3580.45
# 1         Nintendo      3521.83
# 2        Microsoft      1379.28
# 3               PC       258.82
# 4            Atari        97.08
# 5             Sega        79.83
# 6  SNK Corporation         1.44
# 7           Bandai         1.42
# 8  NEC Corporation         0.19
# 9   LG Electronics         0.10

# %%
# By Copmpany
sns.barplot(x="Total_Sales", y="Company", data=total_sales, order=total_sales["Company"])
plt.title("Global Sales")
plt.show()

# %%
# Genres
for genre in vgs.Genre.unique():
    print(genre, end=" ")

cols = ["orange" if x >= 1500 else "grey" for x in vgs.Genre.value_counts()]


sns.countplot(y="Genre", data=vgs, order = vgs["Genre"].value_counts().index, palette=cols)
plt.title("Most Genre Sold")
plt.show()
# Out:
# Sports Platform Racing Role-Playing Puzzle Misc Shooter Simulation Action Fighting Adventure Strategy

# %%
vgs.head()
# Out:
#    Rank                      Name Platform  Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales   Company
# 0     41.49     29.02      3.77         8.46         82.74  Nintendo
# 1     29.08      3.58      6.81         0.77         40.24  Nintendo
# 2     15.85     12.88      3.79         3.31         35.82  Nintendo
# 3     15.75     11.01      3.28         2.96         33.00  Nintendo
# 4     11.27      8.89     10.22         1.00         31.37  Nintendo

# %%
regions = ["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"]
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(20,20))

for i, region in enumerate(regions):
    data = vgs.pivot_table(index="Genre", columns="Company", values=region, aggfunc="sum").sum().sort_values(ascending=False)[:3]
    exp = [.15 if x=="Nintendo" else 0 for x in data.index]
    color = [("#DC143C" if x == "Nintendo" else "#4169E1" if x == "Sony" else "orange" if x == "Microsoft" else "#2EBB57") for x in data.index]
    #reg = [("North America" if x == "NA_Sales" else "Europe" if x == "EU_Sales" else "Japan" if x =="JP_Sales" else "Other Sales" if x=="Other_Sales" else None) for x in regions]
    reg = ("North America" if region == "NA_Sales" else "Europe" if region == "EU_Sales" else "Japan" if region =="JP_Sales" else "Other Sales" if region == "Other_Sales" else None)


    axes[i].pie(data, labels=data.index, rotatelabels=False, labeldistance=1.05, wedgeprops=dict(width=.25), autopct="%1.2f%%",explode=exp,colors=color)
    axes[i].set_xlabel(reg, fontsize=15)

fig.tight_layout()
fig.suptitle("Top 3 Sales Per Region", fontsize=25, y=.65, fontweight="semibold")

plt.show()

# %%
regions = ["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"]
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(20,20))

for i, region in enumerate(regions):
    data = vgs.pivot_table(index="Genre", columns="Company", values=region, aggfunc="sum").sum().sort_values(ascending=False)[:3]
    #exp = [.15 if x=="Nintendo" else 0 for x in data.index]
    exp = [.15 if i == 0 else 0 for i in range(3)]
    #color = [("#DC143C" if x == "Nintendo" else "#4169E1" if x == "Sony" else "orange" if x == "Microsoft" else "#2EBB57") for x in data.index]
    #color = [("#DC143C" if x == "Nintendo" else ("grey" if x == "Sony" else "#4169E1" if x == "Microsoft" else "orange" if x == "Microsoft" else "#2EBB57")) for x in data.index]
    #max_index = data.idxmax()
    #color = ['#DC143C' if index == max_index else '#4169E1' if index == 'Sony' else 'orange' if index == 'Microsoft' else '#2EBB57' for index in data.index]
    color = ["#DC143C" if x == "Nintendo" and data[x] == data.max() else 
             "#4169E1" if x == "Sony" and data[x] == data.max() else 
             "orange" if x == "Microsoft" and data[x] == data.max() else 
             "#2EBB57" if x == "Sega" and data[x] == data.max() else 
             "grey" for x in data.index]

    reg = ("North America" if region == "NA_Sales" else "Europe" if region == "EU_Sales" else "Japan" if region =="JP_Sales" else "Other Sales" if region == "Other_Sales" else None)


    axes[i].pie(data, labels=data.index, rotatelabels=False, labeldistance=1.05, wedgeprops=dict(width=.25), autopct="%1.2f%%",explode=exp,colors=color)
    axes[i].set_xlabel(reg, fontsize=15)

fig.tight_layout()
fig.suptitle("Top 3 Sales Per Region", fontsize=25, y=.65, fontweight="semibold")

plt.show()

# %%
data = vgs.pivot_table(index="Genre", columns="Company", values=region, aggfunc="sum").sum().sort_values(ascending=False)[:3]
reg = []

# %%
sales = vgs.pivot_table(index="Genre", columns="Company", values=["NA_Sales","EU_Sales","JP_Sales","Other_Sales"], aggfunc="sum").sum()
sales
# Out:
#              Company
# EU_Sales     Atari                 5.47
#              Bandai                0.00
#              LG Electronics        0.00
#              Microsoft           387.18
#              NEC Corporation       0.00
#              Nintendo            788.81
#              PC                  139.68
#              SNK Corporation       0.00
#              Sega                  8.11
#              Sony               1104.88
# JP_Sales     Atari                 0.00
#              Bandai                1.42
#              LG Electronics        0.10
#              Microsoft            14.15
#              NEC Corporation       0.19
#              Nintendo            758.51
#              PC                    0.17
#              SNK Corporation       1.44
#              Sega                 43.98
#              Sony                471.06
# NA_Sales     Atari                90.60
#              Bandai                0.00
#              LG Electronics        0.00
# ...

# %%
sns.set_style(style="darkgrid")
plt.figure(figsize=(15,8)).add_gridspec(7, 6)
sns.countplot(y="Year", data=vgs, order = vgs["Year"].value_counts().index, palette="dark:salmon_r")
plt.title("Video Game Sales Per Year")
plt.show()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
# Select the top 5 rank by top 4 year sales
# Select year 2009
tn = vgs[vgs["Year"] == 2009][:5]
# Select year 2008
te = vgs[vgs["Year"] == 2008][:5]
# Select year 2010
tt = vgs[vgs["Year"] == 2010][:5]
# Select year 2007
ts = vgs[vgs["Year"] == 2007][:5]


#cols = [("red" if x >= 9 else "grey") and ("red" if x <= 12 else "grey") for x in te.Global_Sales]
cols0 = ["orange", "grey","grey","grey","grey"]
cols1 = ["orange", "grey", "red","red", "grey"]
#col2
fig, axes = plt.subplots(2,2,figsize=(18,6), dpi=140)

#Two figures up
sns.barplot(x="Global_Sales", y="Name",data=tn,ax=axes[0,0],palette=cols0).set_title("2009")
sns.barplot(x="Global_Sales", y="Name",data=te,errorbar=None,ax=axes[0,1], order=te["Name"], palette=cols1).set_title("2008")



#Two figures down
sns.barplot(x="Global_Sales", y="Name",data=tt,ax=axes[1,0],errorbar=None,order=tt["Name"],palette=cols1).set_title("2010")
sns.barplot(x="Global_Sales", y="Name",data=ts,ax=axes[1,1],palette=cols0).set_title("2007")


fig.suptitle("Game Sales by top year sales",fontsize=25)
fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\user\Desktop\Cursos\Proyecto Data Science\1_Video_Game_Sales_Analysis.ipynb Cell 25 in <cell line: 20>()
#      <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Cursos/Proyecto%20Data%20Science/1_Video_Game_Sales_Analysis.ipynb#X33sZmlsZQ%3D%3D?line=17'>18</a> #Two figures up
#      <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Cursos/Proyecto%20Data%20Science/1_Video_Game_Sales_Analysis.ipynb#X33sZmlsZQ%3D%3D?line=18'>19</a> sns.barplot(x="Global_Sales", y="Name",data=tn,ax=axes[0,0],palette=cols0).set_title("2009")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Cursos/Proyecto%20Data%20Science/1_Video_Game_Sales_Analysis.ipynb#X33sZmlsZQ%3D%3D?line=19'>20</a> sns.barplot(x="Global_Sales", y="Name",data=te,errorbar=None,ax=axes[0,1], order=te["Name"], palette=cols1).set_title("2008")
# ...

# %%
te = vgs[vgs["Year"] == 2008][:5]
# Select year 2010
tt = vgs[vgs["Year"] == 2010][:5]

display(te)
display(tt)
# Out:
#     Rank                      Name Platform  Year         Genre  \
# 2      3            Mario Kart Wii      Wii  2008        Racing
# 39    40   Super Smash Bros. Brawl      Wii  2008      Fighting
# 51    52       Grand Theft Auto IV     X360  2008        Action
# 56    57       Grand Theft Auto IV      PS3  2008        Action
# 88    89  Pokémon Platinum Version       DS  2008  Role-Playing
#
#                Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 2               Nintendo     15.85     12.88      3.79         3.31
# 39              Nintendo      6.75      2.61      2.66         1.02
# 51  Take-Two Interactive      6.76      3.10      0.14         1.03
# 56  Take-Two Interactive      4.76      3.76      0.44         1.62
# 88              Nintendo      2.82      1.78      2.69         0.55
#
#     Global_Sales    Company
# 2          35.82   Nintendo
# 39         13.04   Nintendo
# 51         11.02  Microsoft
# 56         10.57       Sony
# ...

# %%
duplicated = vgs[vgs["Name"].duplicated()]
counts = duplicated["Name"].value_counts()
counts[:10].plot(kind="barh")
plt.show()

# %%
# Display total sales of most wanted game
NFS = vgs[vgs["Name"]=="Need for Speed: Most Wanted"]
total_NFS = NFS["Global_Sales"].sum()
display("Nedd For Speed : Most Wanted Total Sales", total_NFS)

WSR = vgs[vgs["Name"] == "Wii Sports Resort"]
total_WSR = WSR["Global_Sales"].sum()
display("Wii sports Resort Total Salesn", total_WSR)
# Out:
# 'Nedd For Speed : Most Wanted Total Sales'
# 14.079999999999998
# 'Wii sports Resort Total Salesn'
# 33.0

# %% [markdown]
# # video games distribution
# ### probability mass function (PMFs)

# %%
plt.figure(figsize=(20,10))
years_without_null = vgs[vgs['Year'] !=1900]
genre_values = vgs.Genre
sns.histplot(
    data=vgs,
    y="Genre",
    stat="probability",
    binwidth= 1

    )

plt.tight_layout()
plt.show()

# %% [markdown]
# # Funciones empiricas de probablilidad acumulada (CDFs) comulative distribution funtion

# %%
plt.figure(figsize=(15,10))
years_without_null = vgs[vgs['Year'] !=1900]
sns.ecdfplot(
    data = years_without_null,
    x='Year'

)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Proportion'>
